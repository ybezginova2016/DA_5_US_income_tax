# %% [markdown]
# # Income Tax in the US

# %% [markdown]
# Income tax data is collected for different states in the US. It consists of several excel sheets: raw data of total income taxes collected, consumption rate per state, locations and tax codes.
# The dataset is poorly structured and in need of tidying up to improve its quality.
#
# Initial dataset is saved here: https://docs.google.com/spreadsheets/d/1JEhog1MXnOWxJGjfDhJ0BcpvE4bxUxF0cik08UR4EqI/edit?usp=sharing
#
# **Questions to answer during the research:**
#
# 1. Determine state which has the highest amount of taxes per person.
# 2. Determine state with the third largest amount of collected taxes.
# 3. Name region with the smallest value of sum of "Individual Income Taxes" and "Income Taxes"
# 4. Calculate percent changes of personal consumption expenditures between 2018 and 2020 for each state and determine state and year with highest change (example: Florida 2018/2019)
# 5. Determine Region with the highest average Personal Consumption Expenditures per person in 2020
# 6. Prepare a dashboard(s) in one of data visualization to present:
# 1) Amount of taxes collected per person in each state.
# 2) Amount of taxes collected in each state.
# 3) Breakdown of collected taxes (tax types).
# 4) How value of personal consumption expenditures has changed in time.
# 5) Ranking of regions based on average value of personal consumption expenditures per person.

# %% [markdown]
# ### **Research design:**
# - Data reading, overview, data quality check.
# - Cleaning the data, improving the data quality, creating a final dataset for further analysis.
# - Data analysis, searching for insights in data, answering research questions.
# - Making general conclusions and suggestions for further research.

# %% [markdown]
# ## 1.	Data reading & overview

# %% [markdown]
# ### 1.1 Open the file, read all existing sheets with data and get a general infomation about the dataset.

# %% [markdown]
# - ___raw_data___ column

# %%
import pandas as pd
    
raw_data = pd.read_excel('/Users/yuliabezginova/PycharmProjects/income_tax/income_tax_US_082022.xlsx',sheet_name = 'raw_data')
raw_data = raw_data.iloc[3:,]
raw_data.reset_index()
raw_data = raw_data.rename(columns={'State/Region': 'state', 'Population': 'population', 'Tax Name': 'tax_name'})
raw_data
# Out:
#               state  State Code  \
# 3     United States         0.0
# 4     United States         0.0
# 5     United States         0.0
# 6     United States         0.0
# 7     United States         0.0
# ...             ...         ...
# 1730     Washington        48.0
# 1731     Washington        48.0
# 1732     Washington        48.0
# 1733     Washington        48.0
# 1734     Washington        48.0
#
#                                            tax_name Tax Code Taxes Collected  \
# 3                                    Property Taxes      T01        19030677
# 4                    Sales and Gross Receipts Taxes      TA1       458555919
# 5            General Sales and Gross Receipts Taxes      T09       300992624
# 6     Selective Sales   and Gross Receipts    Taxes      TA2       157563295
# 7                     Alcoholic Beverages Sales Tax      T10         6626413
# ...                                             ...      ...             ...
# 1730                           Death and Gift Taxes      T50          167972
# 1731          Documentarty and Stock Transfer Taxes      T51         1072649
# 1732                                Severance Taxes      T53           35055
# 1733                                     Taxes, NEC      T99               0
# 1734                                            NaN      NaN             NaN
#
#        population
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# ...           ...
# 1730          NaN
# 1731          NaN
# 1732          NaN
# 1733          NaN
# 1734  Pop 7425432
#
# [1732 rows x 6 columns]

# %% [markdown]
# **Check the column _'tax_name'_ with categorical variable.**

# %%
raw_data['tax_name'].unique() # call for unique values
# Out:
# array(['Property Taxes', 'Sales and Gross Receipts Taxes',
#        'General Sales and Gross Receipts Taxes',
#        'Selective Sales   and Gross Receipts    Taxes',
#        'Alcoholic Beverages Sales Tax', 'Amusements Sales Tax',
#        'Insurance Premiums Sales Tax', 'Motor Fuels Sales Tax',
#        'Pari-mutuels Sales Tax', 'Public   Utilities   Sales   Tax',
#        'Tobacco   Products   Sales   Tax',
#        'Other   Selective   Sales   and   Gross   Receipts   Taxes',
#        'License   Taxes', 'Alcoholic   Beverages   License',
#        'Amusements License', 'Corporations in General License',
#        'Hunting and Fishing License', 'Motor Vehicle License',
#        'Motor Vehicle Operators License', 'Public Utilities License',
#        'Occupation and Business License, NEC', 'Other//License//Taxes',
#        'Income//Taxes', 'Individual//Income//Taxes',
#        'Corporations//Net//Income//Taxes', 'Other//Taxes',
#        'Death//and//Gift//Taxes',
#        'Documentarty//and//Stock//Transfer//Taxes', 'Severance Taxes',
#        'Taxes, NEC', nan, 'Total_Taxes', 'Property_Taxes',
#        'Sales_and_Gross_Receipts_Taxes',
#        'General_Sales_and_Gross_Receipts_Taxes',
#        'Selective_Sales_and_Gross_Receipts_Taxes',
#        'Alcoholic_Beverages_Sales_Tax', 'Amusements_Sales_Tax',
#        'Insurance_Premiums_Sales_Tax', 'Motor_Fuels_Sales_Tax',
#        'Pari-mutuels_Sales_Tax', 'Public_Utilities_Sales_Tax',
#        'Tobacco_Products_Sales_Tax',
#        'Other_Selective_Sales_and_Gross_Receipts_Taxes', 'License_Taxes',
#        'Alcoholic_Beverages_License', 'Amusements_License',
#        'Corporations_in_General_License', 'Hunting_and_Fishing_License',
#        'Motor_Vehicle_License', 'Motor_Vehicle_Operators_License',
#        'Public_Utilities_License', 'Occupation_and_Business_License,_NEC',
#        'Other_License_Taxes', 'Income_Taxes', 'Individual_Income_Taxes',
#        'Corporations_Net_Income_Taxes', 'Other_Taxes',
#        'Death_and_Gift_Taxes', 'Documentarty_and_Stock_Transfer_Taxes',
#        'Severance_Taxes', 'Taxes,_NEC', 'Total Taxes',
#        'Selective Sales and Gross Receipts Taxes',
#        'Public Utilities Sales Tax', 'Tobacco Products Sales Tax',
#        'Other Selective Sales and Gross Receipts Taxes', 'License Taxes',
#        'Alcoholic Beverages License', 'Other License Taxes',
#        'Income Taxes', 'Individual Income Taxes',
#        'Corporations Net Income Taxes', 'Other Taxes',
#        'Death and Gift Taxes', 'Documentarty and Stock Transfer Taxes',
#        'Property<>Taxes', 'Sales<>and<>Gross<>Receipts<>Taxes',
#        'General<>Sales<>and<>Gross<>Receipts<>Taxes',
#        'Selective<>Sales<>and<>Gross<>Receipts<>Taxes',
#        'Alcoholic<>Beverages<>Sales<>Tax', 'Amusements<>Sales<>Tax',
#        'Insurance<>Premiums<>Sales<>Tax', 'Motor<>Fuels<>Sales<>Tax',
#        'Pari-mutuels<>Sales<>Tax', 'Public<>Utilities<>Sales<>Tax',
#        'Tobacco<>Products<>Sales<>Tax',
#        'Other<>Selective<>Sales<>and<>Gross<>Receipts<>Taxes',
#        'License<>Taxes', 'Alcoholic<>Beverages<>License', 'TotalTaxes',
#        'PropertyTaxes', 'SalesandGrossReceiptsTaxes',
#        'GeneralSalesandGrossReceiptsTaxes',
#        'SelectiveSalesandGrossReceiptsTaxes',
#        'AlcoholicBeveragesSalesTax', 'AmusementsSalesTax',
#        'InsurancePremiumsSalesTax', 'MotorFuelsSalesTax',
#        'Pari-mutuelsSalesTax', 'PublicUtilitiesSalesTax',
#        'TobaccoProductsSalesTax',
#        'OtherSelectiveSalesandGrossReceiptsTaxes', 'LicenseTaxes',
#        'AlcoholicBeveragesLicense', 'AmusementsLicense',
#        'CorporationsinGeneralLicense', 'HuntingandFishingLicense',
#        'MotorVehicleLicense', 'MotorVehicleOperatorsLicense',
#        'PublicUtilitiesLicense', 'OccupationandBusinessLicense,NEC',
#        'OtherLicenseTaxes', 'IncomeTaxes', 'IndividualIncomeTaxes',
#        'CorporationsNetIncomeTaxes', 'OtherTaxes', 'DeathandGiftTaxes',
#        'DocumentartyandStockTransferTaxes', 'SeveranceTaxes', 'Taxes,NEC',
#        'Motor#Vehicle#License', 'Motor#Vehicle#Operators#License',
#        'Public#Utilities#License', 'Occupation#and#Business#License,#NEC',
#        'Other#License#Taxes', 'Income#Taxes', 'Individual#Income#Taxes',
#        'Corporations#Net#Income#Taxes', 'Other#Taxes',
#        'Death#and#Gift#Taxes', 'Documentarty#and#Stock#Transfer#Taxes',
#        'Severance#Taxes', 'Taxes,#NEC', 'Total_N/A_Taxes',
#        'Property_N/A_Taxes',
#        'Sales_N/A_and_N/A_Gross_N/A_Receipts_N/A_Taxes',
#        'General_N/A_Sales_N/A_and_N/A_Gross_N/A_Receipts_N/A_Taxes',
#        'Selective_N/A_Sales_N/A_and_N/A_Gross_N/A_Receipts_N/A_Taxes',
#        'Alcoholic_N/A_Beverages_N/A_Sales_N/A_Tax',
#        'Amusements_N/A_Sales_N/A_Tax',
#        'Insurance_N/A_Premiums_N/A_Sales_N/A_Tax',
#        'Motor_N/A_Fuels_N/A_Sales_N/A_Tax',
#        'Pari-mutuels_N/A_Sales_N/A_Tax',
#        'Public_N/A_Utilities_N/A_Sales_N/A_Tax',
#        'Tobacco_N/A_Products_N/A_Sales_N/A_Tax',
#        'Other_N/A_Selective_N/A_Sales_N/A_and_N/A_Gross_N/A_Receipts_N/A_Taxes',
#        'License_N/A_Taxes', 'Alcoholic_N/A_Beverages_N/A_License',
#        'Amusements_N/A_License',
#        'Corporations_N/A_in_N/A_General_N/A_License',
#        'Hunting_N/A_and_N/A_Fishing_N/A_License',
#        'Motor_N/A_Vehicle_N/A_License',
#        'Motor_N/A_Vehicle_N/A_Operators_N/A_License',
#        'Public_N/A_Utilities_N/A_License',
#        'Occupation_N/A_and_N/A_Business_N/A_License,_N/A_NEC',
#        'Other_N/A_License_N/A_Taxes', 'Income_N/A_Taxes',
#        'Individual_N/A_Income_N/A_Taxes',
#        'Corporations_N/A_Net_N/A_Income_N/A_Taxes', 'Total|Taxes',
#        'Property|Taxes', 'Sales|and|Gross|Receipts|Taxes',
#        'General|Sales|and|Gross|Receipts|Taxes',
#        'Selective|Sales|and|Gross|Receipts|Taxes',
#        'Alcoholic|Beverages|Sales|Tax', 'Amusements|Sales|Tax',
#        'Insurance|Premiums|Sales|Tax', 'Motor|Fuels|Sales|Tax',
#        'Pari-mutuels|Sales|Tax', 'Public|Utilities|Sales|Tax',
#        'Tobacco|Products|Sales|Tax',
#        'Other|Selective|Sales|and|Gross|Receipts|Taxes', 'License|Taxes',
#        'Alcoholic|Beverages|License', 'Amusements|License',
#        'Corporations|in|General|License', 'Hunting|and|Fishing|License',
#        'Motor|Vehicle|License', 'Motor|Vehicle|Operators|License',
#        'Public|Utilities|License', 'Occupation|and|Business|License,|NEC',
#        'Other|License|Taxes', 'Income|Taxes', 'Individual|Income|Taxes',
#        'Corporations|Net|Income|Taxes', 'Other|Taxes',
#        'Death|and|Gift|Taxes', 'Documentarty|and|Stock|Transfer|Taxes',
#        'Severance|Taxes', 'Taxes,|NEC', 'Total;Taxes', 'Property;Taxes',
#        'Sales;and;Gross;Receipts;Taxes',
#        'General;Sales;and;Gross;Receipts;Taxes',
#        'Selective;Sales;and;Gross;Receipts;Taxes',
#        'Alcoholic;Beverages;Sales;Tax', 'Amusements;Sales;Tax',
#        'Insurance;Premiums;Sales;Tax', 'Motor;Fuels;Sales;Tax',
#        'Pari-mutuels;Sales;Tax', 'Public;Utilities;Sales;Tax',
#        'Tobacco;Products;Sales;Tax',
#        'Other;Selective;Sales;and;Gross;Receipts;Taxes', 'License;Taxes',
#        'Alcoholic;Beverages;License', 'Amusements;License',
#        'Corporations;in;General;License', 'Hunting;and;Fishing;License',
#        'Motor;Vehicle;License', 'Total""Taxes', 'Property""Taxes',
#        'Sales""and""Gross""Receipts""Taxes',
#        'General""Sales""and""Gross""Receipts""Taxes',
#        'Selective""Sales""and""Gross""Receipts""Taxes',
#        'Alcoholic""Beverages""Sales""Tax', 'Amusements""Sales""Tax',
#        'Insurance""Premiums""Sales""Tax', 'Motor""Fuels""Sales""Tax',
#        'Pari-mutuels""Sales""Tax', 'Public""Utilities""Sales""Tax',
#        'Tobacco""Products""Sales""Tax',
#        'Other""Selective""Sales""and""Gross""Receipts""Taxes',
#        'License""Taxes', 'Alcoholic""Beverages""License',
#        'Amusements""License', 'Corporations""in""General""License',
#        'Hunting""and""Fishing""License', 'Motor""Vehicle""License',
#        'Total>Taxes', 'Property>Taxes', 'Sales>and>Gross>Receipts>Taxes',
#        'General>Sales>and>Gross>Receipts>Taxes',
#        'Selective>Sales>and>Gross>Receipts>Taxes',
#        'Alcoholic>Beverages>Sales>Tax', 'Amusements>Sales>Tax',
#        'Insurance>Premiums>Sales>Tax', 'Motor>Fuels>Sales>Tax',
#        'Pari-mutuels>Sales>Tax', 'Public>Utilities>Sales>Tax',
#        'Tobacco>Products>Sales>Tax',
#        'Other>Selective>Sales>and>Gross>Receipts>Taxes', 'License>Taxes',
#        'Alcoholic>Beverages>License', 'Amusements>License',
#        'Corporations>in>General>License', 'Hunting>and>Fishing>License',
#        'Motor>Vehicle>License', 'Motor>Vehicle>Operators>License',
#        'Public>Utilities>License', 'Occupation>and>Business>License,>NEC',
#        'Total&Taxes', 'Property&Taxes', 'Sales&and&Gross&Receipts&Taxes',
#        'General&Sales&and&Gross&Receipts&Taxes',
#        'Selective&Sales&and&Gross&Receipts&Taxes',
#        'Alcoholic&Beverages&Sales&Tax', 'Amusements&Sales&Tax',
#        'Insurance&Premiums&Sales&Tax', 'Motor&Fuels&Sales&Tax',
#        'Pari-mutuels&Sales&Tax', 'Public&Utilities&Sales&Tax',
#        'Tobacco&Products&Sales&Tax',
#        'Other&Selective&Sales&and&Gross&Receipts&Taxes', 'License&Taxes',
#        'Alcoholic&Beverages&License', 'Amusements&License',
#        'Corporations&in&General&License', 'Hunting&and&Fishing&License',
#        'Motor&Vehicle&License', 'Motor&Vehicle&Operators&License',
#        'Public&Utilities&License', 'Occupation&and&Business&License,&NEC',
#        'Other&License&Taxes', 'Income&Taxes', 'Individual&Income&Taxes',
#        'Corporations&Net&Income&Taxes', 'Other&Taxes',
#        'Death&and&Gift&Taxes', 'Documentarty&and&Stock&Transfer&Taxes',
#        'Severance&Taxes', 'Taxes,&NEC', 'Total@Taxes', 'Property@Taxes',
#        'Sales@and@Gross@Receipts@Taxes',
#        'General@Sales@and@Gross@Receipts@Taxes',
#        'Selective@Sales@and@Gross@Receipts@Taxes',
#        'Alcoholic@Beverages@Sales@Tax', 'Amusements@Sales@Tax',
#        'Insurance@Premiums@Sales@Tax', 'Motor@Fuels@Sales@Tax',
#        'Pari-mutuels@Sales@Tax', 'Public@Utilities@Sales@Tax',
#        'Tobacco@Products@Sales@Tax',
#        'Other@Selective@Sales@and@Gross@Receipts@Taxes', 'License@Taxes',
#        'Alcoholic@Beverages@License', 'Amusements@License',
#        'Corporations@in@General@License', 'Hunting@and@Fishing@License',
#        'Motor@Vehicle@License', 'Motor@Vehicle@Operators@License',
#        'Public@Utilities@License', 'Occupation@and@Business@License,@NEC',
#        'Other@License@Taxes', 'Income@Taxes', 'Individual@Income@Taxes',
#        'Corporations@Net@Income@Taxes', 'Other@Taxes',
#        'Death@and@Gift@Taxes', 'Documentarty@and@Stock@Transfer@Taxes',
#        'Severance@Taxes', 'Taxes,@NEC', 'Total$%Taxes', 'Property$%Taxes',
#        'Sales$%and$%Gross$%Receipts$%Taxes',
#        'General$%Sales$%and$%Gross$%Receipts$%Taxes',
#        'Selective$%Sales$%and$%Gross$%Receipts$%Taxes',
#        'Alcoholic$%Beverages$%Sales$%Tax', 'Amusements$%Sales$%Tax',
#        'Insurance$%Premiums$%Sales$%Tax', 'Motor$%Fuels$%Sales$%Tax',
#        'Pari-mutuels$%Sales$%Tax', 'Public$%Utilities$%Sales$%Tax',
#        'Tobacco$%Products$%Sales$%Tax',
#        'Other$%Selective$%Sales$%and$%Gross$%Receipts$%Taxes',
#        'License$%Taxes', 'Alcoholic$%Beverages$%License',
#        'Amusements$%License', 'Corporations$%in$%General$%License',
#        'Hunting$%and$%Fishing$%License', 'Motor$%Vehicle$%License',
#        'Motor$%Vehicle$%Operators$%License', 'Public$%Utilities$%License',
#        'Occupation$%and$%Business$%License,$%NEC',
#        'Other$%License$%Taxes', 'Income$%Taxes',
#        'Individual$%Income$%Taxes', 'Corporations$%Net$%Income$%Taxes',
#        'Other$%Taxes', 'Death$%and$%Gift$%Taxes',
#        'Documentarty$%and$%Stock$%Transfer$%Taxes', 'Severance$%Taxes',
#        'Taxes,$%NEC'], dtype=object)

# %% [markdown]
# From the output above we conclude that the column _'tax_name'_ should be cleaned up.

# %%
raw_data.dtypes
# Out:
# state               object
# State Code         float64
# tax_name            object
# Tax Code            object
# Taxes Collected     object
# population          object
# dtype: object

# %%
raw_data['tax_name'] = raw_data['tax_name'].astype(str)

# %%
import re
compiler = re.compile(r'([A-Z]+[a-z]+)|([a-z]+)|(NEC)+')

def tax_name(tax:str):
    norm = ''
    groups = compiler.findall(tax)
    for gr in groups:
        for s in gr:
            if s != '':
                norm+=s + ' '
    norm = norm.strip()
    return norm
raw_data['tax_name'] =  raw_data['tax_name'].apply(tax_name)

# %%
raw_data['tax_name'].unique()
# Out:
# array(['Property Taxes', 'Sales and Gross Receipts Taxes',
#        'General Sales and Gross Receipts Taxes',
#        'Selective Sales and Gross Receipts Taxes',
#        'Alcoholic Beverages Sales Tax', 'Amusements Sales Tax',
#        'Insurance Premiums Sales Tax', 'Motor Fuels Sales Tax',
#        'Pari mutuels Sales Tax', 'Public Utilities Sales Tax',
#        'Tobacco Products Sales Tax',
#        'Other Selective Sales and Gross Receipts Taxes', 'License Taxes',
#        'Alcoholic Beverages License', 'Amusements License',
#        'Corporations in General License', 'Hunting and Fishing License',
#        'Motor Vehicle License', 'Motor Vehicle Operators License',
#        'Public Utilities License', 'Occupation and Business License NEC',
#        'Other License Taxes', 'Income Taxes', 'Individual Income Taxes',
#        'Corporations Net Income Taxes', 'Other Taxes',
#        'Death and Gift Taxes', 'Documentarty and Stock Transfer Taxes',
#        'Severance Taxes', 'Taxes NEC', 'nan', 'Total Taxes',
#        'Salesand Gross Receipts Taxes',
#        'General Salesand Gross Receipts Taxes',
#        'Selective Salesand Gross Receipts Taxes',
#        'Other Selective Salesand Gross Receipts Taxes',
#        'Corporationsin General License', 'Huntingand Fishing License',
#        'Occupationand Business License NEC', 'Deathand Gift Taxes',
#        'Documentartyand Stock Transfer Taxes'], dtype=object)

# %% [markdown]
# **Done!** The column _'tax_name'_ is now clean.

# %% [markdown]
# - ___consumption_data___

# %% [markdown]
# Read the sheet _'consumption_data'_ with a correct labeling:

# %%
consumption_data = pd.read_excel('/Users/yuliabezginova/PycharmProjects/income_tax/income_tax_US_082022.xlsx', sheet_name = 'consumption_data')
consumption_data = consumption_data.iloc[2:5, 1:]

# %%
consumption_data.columns
# Out:
# Index(['Total Personal Consumption Expenditures, by State, 2018–2020',
#        'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6',
#        'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11',
#        'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
#        'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31',
#        'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35',
#        'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39',
#        'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43',
#        'Unnamed: 44', 'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47',
#        'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51',
#        'Unnamed: 52', 'Unnamed: 53', 'Unnamed: 54'],
#       dtype='object')

# %% [markdown]
# Rename the columns accordingly:
#
# Year/State
# United States total
# Connecticut
# Maine
# Massachusetts
# New Hampshire
# Rhode Island
# Vermont
# Delaware
# District of Columbia
# Maryland
# New Jersey
# New York
# Pennsylvania
# Illinois
# Indiana
# Michigan
# Ohio
# Wisconsin
# Iowa
# Kansas
# Minnesota
# Missouri
# Nebraska
# North Dakota
# South Dakota
# Alabama
# Arkansas
# Florida
# Georgia
# Kentucky
# Louisiana
# Mississippi
# North Carolina
# South Carolina
# Tennessee
# Virginia
# West Virginia
# Arizona
# New Mexico
# Oklahoma
# Texas
# Colorado
# Idaho
# Montana
# Utah
# Wyoming
# Alaska
# California
# Hawaii
# Nevada
# Oregon
# Washington
# Net expenditures abroad by U.S. residenta1

# %%
consumption_data = consumption_data.rename(columns={
'Total Personal Consumption Expenditures, by State, 2018–2020': 'year',
       'Unnamed: 2' : 'United States total', 
    'Unnamed: 3': 'Connecticut', 
    'Unnamed: 4': 'Maine', 
    'Unnamed: 5': 'Massachusetts', 
    'Unnamed: 6': 'New Hampshire',
       'Unnamed: 7': 'Rhode Island', 
    'Unnamed: 8': 'Vermont', 
    'Unnamed: 9': 'Delaware', 
    'Unnamed: 10': 'District of Columbia', 
    'Unnamed: 11': 'Maryland',
       'Unnamed: 12': 'New Jersey', 
    'Unnamed: 13': 'New York', 
    'Unnamed: 14': 'Pennsylvania', 
    'Unnamed: 15': 'Illinois',
       'Unnamed: 16': 'Indiana', 
    'Unnamed: 17': 'Michigan', 
    'Unnamed: 18': 'Ohio', 
    'Unnamed: 19': 'Wisconsin',
       'Unnamed: 20': 'Iowa', 
    'Unnamed: 21': 'Kansas', 
    'Unnamed: 22': 'Minnesota', 
    'Unnamed: 23': 'Missouri',
       'Unnamed: 24': 'Nebraska', 
    'Unnamed: 25': 'North Dakota', 
    'Unnamed: 26': 'South Dakota', 
    'Unnamed: 27': 'Alabama',
       'Unnamed: 28': 'Arkansas', 
    'Unnamed: 29': 'Florida', 
    'Unnamed: 30': 'Georgia', 
    'Unnamed: 31': 'Kentucky',
       'Unnamed: 32': 'Louisiana', 
    'Unnamed: 33': 'Mississippi', 
    'Unnamed: 34': 'North Carolina', 
    'Unnamed: 35': 'South Carolina',
       'Unnamed: 36': 'Tennessee', 
    'Unnamed: 37': 'Virginia', 
    'Unnamed: 38': 'West Virginia', 
    'Unnamed: 39': 'Arizona',
       'Unnamed: 40': 'New Mexico', 
    'Unnamed: 41': 'Oklahoma', 
    'Unnamed: 42': 'Texas', 
    'Unnamed: 43': 'Colorado',
       'Unnamed: 44': 'Idaho', 
    'Unnamed: 45': 'Montana', 
    'Unnamed: 46': 'Utah', 
    'Unnamed: 47': 'Wyoming',
       'Unnamed: 48': 'Alaska', 
    'Unnamed: 49': 'California', 
    'Unnamed: 50': 'Hawaii', 
    'Unnamed: 51': 'Nevada',
       'Unnamed: 52': 'Oregon', 
    'Unnamed: 53': 'Washington', 
    'Unnamed: 54' : 'Net expenditures abroad by U.S. residenta1',
})
consumption_data
# Out:
#    year United States total Connecticut  Maine Massachusetts New Hampshire  \
# 2  2018            13913531      181568  60086        364730         69527
# 3  2019            14428676      185316  62130        377584         72030
# 4  2020            14047565      179406  61124        358472         70719
#
#   Rhode Island Vermont Delaware District of Columbia  ... Montana    Utah  \
# 2        45923   30020    44250                47631  ...   43990  113864
# 3        47198   30756    45865                49318  ...   45545  119970
# 4        45397   29545    44834                46454  ...   45719  121445
#
#   Wyoming Alaska California Hawaii  Nevada  Oregon Washington  \
# 2   24352  36645    1835635  64439  120132  172989     347411
# 3   24839  37780    1921463  66977  125927  180750     363100
# 4   24467  35636    1835981  63427  123054  178375     354219
#
#   Net expenditures abroad by U.S. residenta1
# 2                                      10461
# 3                                      11432
# 4                                      11110
#
# [3 rows x 54 columns]

# %% [markdown]
# Let's create a panel data out of _'consumption_data'_.

# %%
consumption_data = pd.melt(consumption_data, id_vars="year")
consumption_data
# Out:
#      year                                    variable     value
# 0    2018                         United States total  13913531
# 1    2019                         United States total  14428676
# 2    2020                         United States total  14047565
# 3    2018                                 Connecticut    181568
# 4    2019                                 Connecticut    185316
# ..    ...                                         ...       ...
# 154  2019                                  Washington    363100
# 155  2020                                  Washington    354219
# 156  2018  Net expenditures abroad by U.S. residenta1     10461
# 157  2019  Net expenditures abroad by U.S. residenta1     11432
# 158  2020  Net expenditures abroad by U.S. residenta1     11110
#
# [159 rows x 3 columns]

# %% [markdown]
# Rename and sort values in the _'consumption_data'_ dataset.

# %%
consumption_data = consumption_data.rename(columns={'variable': 'state', 'value': 'consumption'})
consumption_data.sort_values(by='consumption', ascending=False)
# Out:
#      year                                       state consumption
# 1    2019                         United States total    14428676
# 2    2020                         United States total    14047565
# 0    2018                         United States total    13913531
# 142  2019                                  California     1921463
# 143  2020                                  California     1835981
# ..    ...                                         ...         ...
# 137  2020                                     Wyoming       24467
# 135  2018                                     Wyoming       24352
# 157  2019  Net expenditures abroad by U.S. residenta1       11432
# 158  2020  Net expenditures abroad by U.S. residenta1       11110
# 156  2018  Net expenditures abroad by U.S. residenta1       10461
#
# [159 rows x 3 columns]

# %%
locations_data = pd.read_excel('/Users/yuliabezginova/PycharmProjects/income_tax/income_tax_US_082022.xlsx', sheet_name = 'locations')
locations_data
# Out:
#     Location Code   Latitude   Longitude
# 0               0  37.090240  -95.712891
# 1               1  32.318230  -86.902298
# 2               2  66.160507 -153.369141
# 3               3  34.048927 -111.093735
# 4               4  34.799999  -92.199997
# 5               5  36.778259 -119.417931
# 6               6  39.113014 -105.358887
# 7               7  41.599998  -72.699997
# 8               8  39.000000  -75.500000
# 9              10  27.994402  -81.760254
# 10             11  33.247875  -83.441162
# 11             12  19.741755 -155.844437
# 12             13  44.068203 -114.742043
# 13             14  40.000000  -89.000000
# 14             15  40.273502  -86.126976
# 15             16  42.032974  -93.581543
# 16             17  38.500000  -98.000000
# 17             18  37.839333  -84.270020
# 18             19  30.391830  -92.329102
# 19             20  45.367584  -68.972168
# 20             21  39.045753  -76.641273
# 21             22  42.407211  -71.382439
# 22             23  44.182205  -84.506836
# 23             24  46.392410  -94.636230
# 24             25  33.000000  -90.000000
# 25             26  38.573936  -92.603760
# 26             27  46.965260 -109.533691
# 27             28  41.500000 -100.000000
# 28             29  39.876019 -117.224121
# 29             30  44.000000  -71.500000
# 30             31  39.833851  -74.871826
# 31             32  34.307144 -106.018066
# 32             33  43.000000  -75.000000
# 33             34  35.782169  -80.793457
# 34             35  47.650589 -100.437012
# 35             36  40.367474  -82.996216
# 36             37  36.084621  -96.921387
# 37             38  44.000000 -120.500000
# 38             39  41.203323  -77.194527
# 39             40  41.742325  -71.742332
# 40             41  33.836082  -81.163727
# 41             42  44.500000 -100.000000
# 42             43  35.860119  -86.660156
# 43             44  31.000000 -100.000000
# 44             45  39.419220 -111.950684
# 45             46  44.000000  -72.699997
# 46             47  37.926868  -78.024902
# 47             48  47.751076 -120.740135
# 48             49  39.000000  -80.500000
# 49             50  44.500000  -89.500000
# 50             51  43.075970 -107.290283

# %%
tax_selector_data = pd.read_excel('/Users/yuliabezginova/PycharmProjects/income_tax/income_tax_US_082022.xlsx', sheet_name = 'tax_selector')
tax_selector_data
# Out:
#    Tax Code Include?
# 0       T00      yes
# 1       T01      yes
# 2       TA1       no
# 3       T09       no
# 4       TA2       no
# 5       T10       no
# 6       T11       no
# 7       T12       no
# 8       T13       no
# 9       T14       no
# 10      T15       no
# 11      T16       no
# 12      T19       no
# 13      TA3       no
# 14      T20       no
# 15      T21       no
# 16      T22      yes
# 17      T23       no
# 18      T24       no
# 19      T25       no
# 20      T27       no
# 21      T28       no
# 22      T29       no
# 23      TA4      yes
# 24      T40      yes
# 25      T41      yes
# 26      TA5       no
# 27      T50       no
# 28      T51       no
# 29      T53       no
# 30      T99       no

# %% [markdown]
# Combine three datasets in one: _'raw_data', 'consumption_data', 'tax_selector'_ in one dataset.

# %%
data = raw_data.merge(consumption_data, on='state', how='outer')
data
# Out:
#                                            state  State Code  \
# 0                                  United States         0.0
# 1                                  United States         0.0
# 2                                  United States         0.0
# 3                                  United States         0.0
# 4                                  United States         0.0
# ...                                          ...         ...
# 4936                        District of Columbia         NaN
# 4937                        District of Columbia         NaN
# 4938  Net expenditures abroad by U.S. residenta1         NaN
# 4939  Net expenditures abroad by U.S. residenta1         NaN
# 4940  Net expenditures abroad by U.S. residenta1         NaN
#
#                                       tax_name Tax Code Taxes Collected  \
# 0                               Property Taxes      T01        19030677
# 1               Sales and Gross Receipts Taxes      TA1       458555919
# 2       General Sales and Gross Receipts Taxes      T09       300992624
# 3     Selective Sales and Gross Receipts Taxes      TA2       157563295
# 4                Alcoholic Beverages Sales Tax      T10         6626413
# ...                                        ...      ...             ...
# 4936                                       NaN      NaN             NaN
# 4937                                       NaN      NaN             NaN
# 4938                                       NaN      NaN             NaN
# 4939                                       NaN      NaN             NaN
# 4940                                       NaN      NaN             NaN
#
#      population  year consumption
# 0           NaN   NaN         NaN
# 1           NaN   NaN         NaN
# 2           NaN   NaN         NaN
# 3           NaN   NaN         NaN
# 4           NaN   NaN         NaN
# ...         ...   ...         ...
# 4936        NaN  2019       49318
# 4937        NaN  2020       46454
# 4938        NaN  2018       10461
# 4939        NaN  2019       11432
# 4940        NaN  2020       11110
#
# [4941 rows x 8 columns]

# %%
data = data.merge(tax_selector_data, on='Tax Code', how='outer')
data
# Out:
#               state  State Code        tax_name Tax Code Taxes Collected  \
# 0     United States         0.0  Property Taxes      T01        19030677
# 1       Connecticut         7.0  Property Taxes      T01               X
# 2       Connecticut         7.0  Property Taxes      T01               X
# 3       Connecticut         7.0  Property Taxes      T01               X
# 4             Maine        20.0  Property Taxes      T01           38643
# ...             ...         ...             ...      ...             ...
# 4936         Oregon        38.0     Total Taxes      T00        11839680
# 4937         Oregon        38.0     Total Taxes      T00        11839680
# 4938     Washington        48.0     Total Taxes      T00        23997592
# 4939     Washington        48.0     Total Taxes      T00        23997592
# 4940     Washington        48.0     Total Taxes      T00        23997592
#
#      population  year consumption Include?
# 0           NaN   NaN         NaN      yes
# 1           NaN  2018      181568      yes
# 2           NaN  2019      185316      yes
# 3           NaN  2020      179406      yes
# 4           NaN  2018       60086      yes
# ...         ...   ...         ...      ...
# 4936        NaN  2019      180750      yes
# 4937        NaN  2020      178375      yes
# 4938        NaN  2018      347411      yes
# 4939        NaN  2019      363100      yes
# 4940        NaN  2020      354219      yes
#
# [4941 rows x 9 columns]

# %% [markdown]
# **A dataset _'data'_ is a final dataset for further manipulation and analysis.**

# %%
data.columns # getting columns names
# Out:
# Index(['state', 'State Code', 'tax_name', 'Tax Code', 'Taxes Collected',
#        'population', 'year', 'consumption', 'Include?'],
#       dtype='object')

# %%
# rename columns in the final dataset
data = data.rename(columns={'State Code': 'state_code',
                            'Tax Name': 'tax_name',
                            'Tax Code': 'tax_code',
                            'Taxes Collected': 'tax_collected',
                            'Population': 'population',
                            'Include?': 'include?'
                           })
data
# Out:
#               state  state_code        tax_name tax_code tax_collected  \
# 0     United States         0.0  Property Taxes      T01      19030677
# 1       Connecticut         7.0  Property Taxes      T01             X
# 2       Connecticut         7.0  Property Taxes      T01             X
# 3       Connecticut         7.0  Property Taxes      T01             X
# 4             Maine        20.0  Property Taxes      T01         38643
# ...             ...         ...             ...      ...           ...
# 4936         Oregon        38.0     Total Taxes      T00      11839680
# 4937         Oregon        38.0     Total Taxes      T00      11839680
# 4938     Washington        48.0     Total Taxes      T00      23997592
# 4939     Washington        48.0     Total Taxes      T00      23997592
# 4940     Washington        48.0     Total Taxes      T00      23997592
#
#      population  year consumption include?
# 0           NaN   NaN         NaN      yes
# 1           NaN  2018      181568      yes
# 2           NaN  2019      185316      yes
# 3           NaN  2020      179406      yes
# 4           NaN  2018       60086      yes
# ...         ...   ...         ...      ...
# 4936        NaN  2019      180750      yes
# 4937        NaN  2020      178375      yes
# 4938        NaN  2018      347411      yes
# 4939        NaN  2019      363100      yes
# 4940        NaN  2020      354219      yes
#
# [4941 rows x 9 columns]

# %% [markdown]
# ## 2.	Data pre-processing

# %% [markdown]
# ### 2.1 Work with missings

# %% [markdown]
# **Let's check the share of missings in the data in each column.**

# %%
pd.DataFrame(round(data.isna().mean()*100,)).style.background_gradient('coolwarm')
# Out:
# <style type="text/css">
# #T_1c4b0_row0_col0 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_1c4b0_row1_col0 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_1c4b0_row2_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_1c4b0_row3_col0, #T_1c4b0_row4_col0, #T_1c4b0_row8_col0 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_1c4b0_row5_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_1c4b0_row6_col0, #T_1c4b0_row7_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1c4b0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1c4b0_level0_row0" class="row_heading level0 row0" >state</th>
#       <td id="T_1c4b0_row0_col0" class="data row0 col0" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c4b0_level0_row1" class="row_heading level0 row1" >state_code</th>
#       <td id="T_1c4b0_row1_col0" class="data row1 col0" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c4b0_level0_row2" class="row_heading level0 row2" >tax_name</th>
#       <td id="T_1c4b0_row2_col0" class="data row2 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c4b0_level0_row3" class="row_heading level0 row3" >tax_code</th>
#       <td id="T_1c4b0_row3_col0" class="data row3 col0" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c4b0_level0_row4" class="row_heading level0 row4" >tax_collected</th>
#       <td id="T_1c4b0_row4_col0" class="data row4 col0" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c4b0_level0_row5" class="row_heading level0 row5" >population</th>
#       <td id="T_1c4b0_row5_col0" class="data row5 col0" >97.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c4b0_level0_row6" class="row_heading level0 row6" >year</th>
#       <td id="T_1c4b0_row6_col0" class="data row6 col0" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c4b0_level0_row7" class="row_heading level0 row7" >consumption</th>
#       <td id="T_1c4b0_row7_col0" class="data row7 col0" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1c4b0_level0_row8" class="row_heading level0 row8" >include?</th>
#       <td id="T_1c4b0_row8_col0" class="data row8 col0" >5.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **From the output above we can conclude that there are 97% of missings in _'population'_ column. We have to process this later.**
#
# **All the other columns contain < 10% of missings, which can be either dropped or filled in with median values.**

# %%
data.count()
# Out:
# state            4881
# state_code       4863
# tax_name         4932
# tax_code         4711
# tax_collected    4711
# population        152
# year             4809
# consumption      4809
# include?         4711
# dtype: int64

# %% [markdown]
# Fill in the missings in _'consumption'_ with median values.

# %%
import warnings
warnings.simplefilter("ignore", category=RuntimeWarning)

pd.options.mode.chained_assignment = None

# %%
data['consumption'] = data['consumption'].fillna(data.groupby('state')['consumption'].transform('median'))
data['consumption'].isna().sum() / len(data)
# Out:
# 0.02671523982999393

# %% [markdown]
# **From the above output, we can see that the column _'consumption'_ contains 2.6% of missings, which can be safely dropped.**
#
#
# **Also we can drop missings in the other columns if the share of missing values is less than 10%. Let's check this, and if so, drop.**

# %%
data['state_code'].isna().sum() / len(data)
# Out:
# 0.015786278081360048

# %%
data['tax_name'].isna().sum() / len(data)
# Out:
# 0.0018214936247723133

# %%
data['tax_code'].isna().sum() / len(data)
# Out:
# 0.04654928152195912

# %%
data['tax_collected'].isna().sum() / len(data)
# Out:
# 0.04654928152195912

# %%
data['year'].isna().sum() / len(data)
# Out:
# 0.02671523982999393

# %%
data['consumption'].isna().sum() / len(data)
# Out:
# 0.02671523982999393

# %%
data['include?'].isna().sum() / len(data)
# Out:
# 0.04654928152195912

# %%
data = data.dropna(subset=['state_code', 'tax_name', 'tax_code', 'tax_collected', 'year', 'consumption', 'include?'])
print(data['state_code'].isna().sum())
print(data['tax_name'].isna().sum())
print(data['tax_code'].isna().sum())
print(data['tax_collected'].isna().sum())
print(data['year'].isna().sum())
print(data['consumption'].isna().sum())
print(data['include?'].isna().sum())
# Out:
# 0
# 0
# 0
# 0
# 0
# 0
# 0

# %%
print(data[data['tax_collected'] == 'X'].count() / len(data)*100)
# Out:
# state            9.096774
# state_code       9.096774
# tax_name         9.096774
# tax_code         9.096774
# tax_collected    9.096774
# population       0.000000
# year             9.096774
# consumption      9.096774
# include?         9.096774
# dtype: float64

# %% [markdown]
# From the output above we can conclude that the share of 'tax_collected' == 'X' values is less than 10% in the dataset, meaning these values can be safely dropped.

# %%
data = data.drop(data[data['tax_collected'] == 'X'].index)

# %%
data
# Out:
#               state  state_code        tax_name tax_code tax_collected  \
# 4             Maine        20.0  Property Taxes      T01         38643
# 5             Maine        20.0  Property Taxes      T01         38643
# 6             Maine        20.0  Property Taxes      T01         38643
# 7     Massachusetts        22.0  Property Taxes      T01          6598
# 8     Massachusetts        22.0  Property Taxes      T01          6598
# ...             ...         ...             ...      ...           ...
# 4936         Oregon        38.0     Total Taxes      T00      11839680
# 4937         Oregon        38.0     Total Taxes      T00      11839680
# 4938     Washington        48.0     Total Taxes      T00      23997592
# 4939     Washington        48.0     Total Taxes      T00      23997592
# 4940     Washington        48.0     Total Taxes      T00      23997592
#
#      population  year  consumption include?
# 4           NaN  2018      60086.0      yes
# 5           NaN  2019      62130.0      yes
# 6           NaN  2020      61124.0      yes
# 7           NaN  2018     364730.0      yes
# 8           NaN  2019     377584.0      yes
# ...         ...   ...          ...      ...
# 4936        NaN  2019     180750.0      yes
# 4937        NaN  2020     178375.0      yes
# 4938        NaN  2018     347411.0      yes
# 4939        NaN  2019     363100.0      yes
# 4940        NaN  2020     354219.0      yes
#
# [4227 rows x 9 columns]

# %% [markdown]
# ### 2.2 Work with duplicates

# %%
data.duplicated().sum() # check whether there are duplicates
# Out:
# 0

# %%
data.columns # displaying what columns the dataset
# Out:
# Index(['state', 'state_code', 'tax_name', 'tax_code', 'tax_collected',
#        'population', 'year', 'consumption', 'include?'],
#       dtype='object')

# %%
print(data['state'].unique())
# Out:
# ['Maine' 'Massachusetts' 'New Hampshire' 'Rhode Island' 'Vermont'
#  'New Jersey' 'Pennsylvania' 'Illinois' 'Indiana' 'Michigan' 'Wisconsin'
#  'Iowa' 'Kansas' 'Minnesota' 'Missouri' 'Nebraska' 'North Dakota'
#  'Georgia' 'Maryland' 'South Carolina' 'Virginia' 'West Virginia'
#  'Arkansas' 'Louisiana' 'Alabama' 'Kentucky' 'Mississippi' 'Arizona'
#  'Montana' 'Nevada' 'New Mexico' 'Wyoming' 'California' 'Alaska' 'Oregon'
#  'Washington' 'Connecticut' 'New York' 'Ohio' 'South Dakota' 'Delaware'
#  'Florida' 'North Carolina' 'Oklahoma' 'Texas' 'Tennessee' 'Colorado'
#  'Idaho' 'Utah' 'Hawaii']

# %% [markdown]
# **There are no either explicit or implicit duplicates in the dataset. We save this dataset as a final for further analysis.**

# %% [markdown]
# ### 2.3 Changing data types

# %% [markdown]
# Check the type of each variable in the final dataset.

# %%
data.dtypes
# Out:
# state             object
# state_code       float64
# tax_name          object
# tax_code          object
# tax_collected     object
# population        object
# year              object
# consumption      float64
# include?          object
# dtype: object

# %% [markdown]
# We can see that some variables' types should be changed from _object_ to _int_ or _str_.

# %%
data['state'] = data['state'].astype(str)
data['state_code'] = data['state_code'].astype(str)
data['tax_collected'] = data['tax_collected'].astype(int) # changinh the type to integer
data['year'] = data['year'].astype(int)
data['consumption'] = data['consumption'].astype(int)

# %% [markdown]
# Let's check the variables' types now.

# %%
data.dtypes
# Out:
# state            object
# state_code       object
# tax_name         object
# tax_code         object
# tax_collected     int64
# population       object
# year              int64
# consumption       int64
# include?         object
# dtype: object

# %% [markdown]
# **Done!**

# %% [markdown]
# ### 2.4 Processing _'population'_ column

# %% [markdown]
# Remove the column _'population'_ from the dataset and add it in more readable format.

# %%
data = data.drop(labels=['population'], axis=1)
data
# Out:
#               state state_code        tax_name tax_code  tax_collected  year  \
# 4             Maine       20.0  Property Taxes      T01          38643  2018
# 5             Maine       20.0  Property Taxes      T01          38643  2019
# 6             Maine       20.0  Property Taxes      T01          38643  2020
# 7     Massachusetts       22.0  Property Taxes      T01           6598  2018
# 8     Massachusetts       22.0  Property Taxes      T01           6598  2019
# ...             ...        ...             ...      ...            ...   ...
# 4936         Oregon       38.0     Total Taxes      T00       11839680  2019
# 4937         Oregon       38.0     Total Taxes      T00       11839680  2020
# 4938     Washington       48.0     Total Taxes      T00       23997592  2018
# 4939     Washington       48.0     Total Taxes      T00       23997592  2019
# 4940     Washington       48.0     Total Taxes      T00       23997592  2020
#
#       consumption include?
# 4           60086      yes
# 5           62130      yes
# 6           61124      yes
# 7          364730      yes
# 8          377584      yes
# ...           ...      ...
# 4936       180750      yes
# 4937       178375      yes
# 4938       347411      yes
# 4939       363100      yes
# 4940       354219      yes
#
# [4227 rows x 8 columns]

# %% [markdown]
# Adding _'population'_ columns in a readable format to the processed dataset. First, we create a function which split and distribute the values from _'raw_data'_ dataset.

# %%
population_by_state = raw_data[raw_data['population'].notna()][['state', 'population']]

def split_population(population:str):
    separated = population.strip().split(' ')
    return separated[1]

population_by_state['population'] = population_by_state['population'].apply(split_population)

# %%
population_by_state
# Out:
#                state population
# 33     United States  325147121
# 68       Connecticut    3573880
# 101            Maine    1335063
# 134    Massachusetts    6863246
# 167    New Hampshire    1349767
# 200     Rhode Island    1056486
# 233          Vermont     624525
# 268       New Jersey    8888543
# 301         New York   19590719
# 334     Pennsylvania   12790447
# 369         Illinois   12786196
# 402          Indiana    6660082
# 435         Michigan    9976447
# 468             Ohio   11664129
# 501        Wisconsin    5792051
# 536             Iowa    3143637
# 569           Kansas    2910689
# 602        Minnesota    5568155
# 635         Missouri    6108612
# 668         Nebraska    1917575
# 701     North Dakota     755176
# 734     South Dakota     873286
# 769         Delaware     957078
# 802               DC     695691
# 835          Florida   20976812
# 868          Georgia   10413055
# 901         Maryland    6024891
# 934   North Carolina   10270800
# 967   South Carolina    5021219
# 1000        Virginia    8465207
# 1033   West Virginia    1817048
# 1068        Arkansas    3002997
# 1101       Louisiana    4670818
# 1134        Oklahoma    3932640
# 1167           Texas   28322717
# 1202         Alabama    4875120
# 1235        Kentucky    4453874
# 1268     Mississippi    2989663
# 1301       Tennessee    6708794
# 1336         Arizona    7048876
# 1369        Colorado    5615902
# 1402           Idaho    1718904
# 1435         Montana    1053090
# 1468          Nevada    2972405
# 1501      New Mexico    2093395
# 1534            Utah    3103118
# 1567         Wyoming     578934
# 1602      California   39399349
# 1635          Alaska     739786
# 1668          Hawaii    1424203
# 1701          Oregon    4146592
# 1734      Washington    7425432

# %% [markdown]
# Second, merge the newly created table _'population_by_state'_ with the processed dataset.

# %%
data = data.merge(population_by_state, on='state', how='outer')
data
# Out:
#               state state_code                        tax_name tax_code  \
# 0             Maine       20.0                  Property Taxes      T01
# 1             Maine       20.0                  Property Taxes      T01
# 2             Maine       20.0                  Property Taxes      T01
# 3             Maine       20.0  Sales and Gross Receipts Taxes      TA1
# 4             Maine       20.0  Sales and Gross Receipts Taxes      TA1
# ...             ...        ...                             ...      ...
# 4224         Hawaii       12.0                     Total Taxes      T00
# 4225         Hawaii       12.0                     Total Taxes      T00
# 4226         Hawaii       12.0                     Total Taxes      T00
# 4227  United States        NaN                             NaN      NaN
# 4228             DC        NaN                             NaN      NaN
#
#       tax_collected    year  consumption include? population
# 0           38643.0  2018.0      60086.0      yes    1335063
# 1           38643.0  2019.0      62130.0      yes    1335063
# 2           38643.0  2020.0      61124.0      yes    1335063
# 3         2165142.0  2018.0      60086.0       no    1335063
# 4         2165142.0  2019.0      62130.0       no    1335063
# ...             ...     ...          ...      ...        ...
# 4224      7029026.0  2018.0      64439.0      yes    1424203
# 4225      7029026.0  2019.0      66977.0      yes    1424203
# 4226      7029026.0  2020.0      63427.0      yes    1424203
# 4227            NaN     NaN          NaN      NaN  325147121
# 4228            NaN     NaN          NaN      NaN     695691
#
# [4229 rows x 9 columns]

# %%
data = data.dropna(subset=['state_code', 'tax_name', 'tax_code', 'tax_collected', 'year', 'consumption', 'include?'])
print(data['state_code'].isna().sum())
print(data['tax_name'].isna().sum())
print(data['tax_code'].isna().sum())
print(data['tax_collected'].isna().sum())
print(data['year'].isna().sum())
print(data['consumption'].isna().sum())
print(data['include?'].isna().sum())
# Out:
# 0
# 0
# 0
# 0
# 0
# 0
# 0

# %% [markdown]
# Check the variables' types.

# %%
data.dtypes
# Out:
# state             object
# state_code        object
# tax_name          object
# tax_code          object
# tax_collected    float64
# year             float64
# consumption      float64
# include?          object
# population        object
# dtype: object

# %%
data['tax_collected'] = data['tax_collected'].astype(int)
data['consumption'] = data['consumption'].astype(int)
data['population'] = data['population'].astype(int)

# %%
data.dtypes
# Out:
# state             object
# state_code        object
# tax_name          object
# tax_code          object
# tax_collected      int64
# year             float64
# consumption        int64
# include?          object
# population         int64
# dtype: object

# %% [markdown]
# **Done!**

# %% [markdown]
# ### 2.5 Keep only 'included?' as no.

# %% [markdown]
# As a final step of the analysis, we should keep for further analysis only if taxes **not included**, meaning to filter the dataset in the column 'include?' by _'no'_.

# %%
data_clean = data[data['include?'] == 'no']

# %%
# writing to csv
clean_income_tax_data = data_clean.to_csv('/Users/yuliabezginova/PycharmProjects/income_tax/clean_income_tax_data.csv')

# %%
# writing to xlsx
clean_income_tax_data = data_clean.to_excel('/Users/yuliabezginova/PycharmProjects/income_tax/clean_income_tax_data.xlsx')

# %% [markdown]
# Proceed with data analysis using the preprocessed dataset.

# %% [markdown]
# ## 3.	Data Analysis & Research Questions

# %% [markdown]
# Reading the pre-processed data.

# %%
data_clean = pd.read_csv('/Users/yuliabezginova/PycharmProjects/income_tax/clean_income_tax_data.csv')
data_clean = data_clean.drop(labels=['Unnamed: 0'], axis=1)
data_clean
# Out:
#        state  state_code                                tax_name tax_code  \
# 0      Maine        20.0          Sales and Gross Receipts Taxes      TA1
# 1      Maine        20.0          Sales and Gross Receipts Taxes      TA1
# 2      Maine        20.0          Sales and Gross Receipts Taxes      TA1
# 3      Maine        20.0  General Sales and Gross Receipts Taxes      T09
# 4      Maine        20.0  General Sales and Gross Receipts Taxes      T09
# ...      ...         ...                                     ...      ...
# 3415  Hawaii        12.0   Documentarty and Stock Transfer Taxes      T51
# 3416  Hawaii        12.0   Documentarty and Stock Transfer Taxes      T51
# 3417  Hawaii        12.0                               Taxes NEC      T99
# 3418  Hawaii        12.0                               Taxes NEC      T99
# 3419  Hawaii        12.0                               Taxes NEC      T99
#
#       tax_collected    year  consumption include?  population
# 0           2165142  2018.0        60086       no     1335063
# 1           2165142  2019.0        62130       no     1335063
# 2           2165142  2020.0        61124       no     1335063
# 3           1441867  2018.0        60086       no     1335063
# 4           1441867  2019.0        62130       no     1335063
# ...             ...     ...          ...      ...         ...
# 3415          94537  2019.0        66977       no     1424203
# 3416          94537  2020.0        63427       no     1424203
# 3417              0  2018.0        64439       no     1424203
# 3418              0  2019.0        66977       no     1424203
# 3419              0  2020.0        63427       no     1424203
#
# [3420 rows x 9 columns]

# %% [markdown]
# Rename the column _'state'_ to _'region'_ as required in the task.

# %%
data_clean = data_clean.rename(columns={'state': 'region'})
data_clean
# Out:
#       region  state_code                                tax_name tax_code  \
# 0      Maine        20.0          Sales and Gross Receipts Taxes      TA1
# 1      Maine        20.0          Sales and Gross Receipts Taxes      TA1
# 2      Maine        20.0          Sales and Gross Receipts Taxes      TA1
# 3      Maine        20.0  General Sales and Gross Receipts Taxes      T09
# 4      Maine        20.0  General Sales and Gross Receipts Taxes      T09
# ...      ...         ...                                     ...      ...
# 3415  Hawaii        12.0   Documentarty and Stock Transfer Taxes      T51
# 3416  Hawaii        12.0   Documentarty and Stock Transfer Taxes      T51
# 3417  Hawaii        12.0                               Taxes NEC      T99
# 3418  Hawaii        12.0                               Taxes NEC      T99
# 3419  Hawaii        12.0                               Taxes NEC      T99
#
#       tax_collected    year  consumption include?  population
# 0           2165142  2018.0        60086       no     1335063
# 1           2165142  2019.0        62130       no     1335063
# 2           2165142  2020.0        61124       no     1335063
# 3           1441867  2018.0        60086       no     1335063
# 4           1441867  2019.0        62130       no     1335063
# ...             ...     ...          ...      ...         ...
# 3415          94537  2019.0        66977       no     1424203
# 3416          94537  2020.0        63427       no     1424203
# 3417              0  2018.0        64439       no     1424203
# 3418              0  2019.0        66977       no     1424203
# 3419              0  2020.0        63427       no     1424203
#
# [3420 rows x 9 columns]

# %% [markdown]
# **Let's observe the numerial variables via histograms and check if there are any outstanding values.**

# %%
data_clean.hist(bins=50, figsize=(15, 20));
None

# %% [markdown]
# ### _Decriptive Statistics_

# %% [markdown]
# **Let's check descriptive statistics for each numerical variable.**

# %%
data_clean.columns
# Out:
# Index(['region', 'state_code', 'tax_name', 'tax_code', 'tax_collected', 'year',
#        'consumption', 'include?', 'population'],
#       dtype='object')

# %% [markdown]
# - **_tax_collected_**

# %%
data['tax_collected'].describe()

import matplotlib.pyplot as plt

# descriptive statistics
print(data['tax_collected'].describe())
data.boxplot(column='tax_collected', figsize=(3,7));
plt.show()
data['tax_collected'].hist(bins=30, range=(0, 50), figsize=(10, 5));
# Out:
# count    4.227000e+03
# mean     2.112125e+06
# std      7.670679e+06
# min      0.000000e+00
# 25%      1.879600e+04
# 50%      1.462270e+05
# 75%      9.968480e+05
# max      1.556919e+08
# Name: tax_collected, dtype: float64

# %% [markdown]
# ### Conclusion
#
# - mean differs from median (50%), meaning there are some anomalies or outliers in the dataset;
# - standard deviation is 4 times bigger than the mean, meaning the range is too large and the data is left-handed (positively) scattered.

# %% [markdown]
# - **_consumption_**

# %%
data['consumption'].describe()

import matplotlib.pyplot as plt

# descriptive statistics
print(data['consumption'].describe())
data.boxplot(column='consumption', figsize=(3,7));
plt.show()
data['consumption'].hist(bins=30, figsize=(10, 5));
# Out:
# count    4.227000e+03
# mean     2.833720e+05
# std      3.332602e+05
# min      2.435200e+04
# 25%      7.427600e+04
# 50%      1.783750e+05
# 75%      3.647300e+05
# max      1.921463e+06
# Name: consumption, dtype: float64

# %% [markdown]
# ### Conclusion:
# - mean is quite close to median (50%), meaning there are no so many outliers in the dataset.

# %%
(
    data_clean
    .pivot_table(index='consumption', values='tax_collected', aggfunc='median')
    .plot(grid=True, figsize=(12, 5))
);

# %% [markdown]
# ### 3.1 Determine state which has the highest amount of taxes per person.

# %% [markdown]
# Calculate in a separate column with tax per persone values in each state.

# %%
data_clean['tax_per_person'] = data_clean['tax_collected'] / data_clean['population']
data_clean['tax_per_person']
# Out:
# 0       1.621753
# 1       1.621753
# 2       1.621753
# 3       1.079999
# 4       1.079999
#           ...
# 3415    0.066379
# 3416    0.066379
# 3417    0.000000
# 3418    0.000000
# 3419    0.000000
# Name: tax_per_person, Length: 3420, dtype: float64

# %% [markdown]
# Group the data based on 'state' and mean value of the calculated tax per person amount.

# %%
tax_per_person = data_clean.groupby('region')['tax_per_person'].agg(['mean']).sort_values(by='mean', ascending=False).head(10)
tax_per_person.reset_index(inplace=True) # resetting indexed from 0 again

tax_per_person
# Out:
#          region      mean
# 0  North Dakota  0.382194
# 1        Hawaii  0.370807
# 2        Nevada  0.286548
# 3    Washington  0.271148
# 4       Wyoming  0.251399
# 5       Vermont  0.241748
# 6   Connecticut  0.223660
# 7     Minnesota  0.213378
# 8  South Dakota  0.201281
# 9      Maryland  0.187856

# %%
print(tax_per_person[tax_per_person['mean'] == tax_per_person['mean'].max()])
# Out:
#          region      mean
# 0  North Dakota  0.382194

# %%
data_clean_grouped = data_clean.groupby('region')[['tax_collected', 'consumption', 'tax_per_person']].agg('median').sort_values(by='consumption', ascending=False)
data_clean_grouped = data_clean_grouped.dropna()
display(data_clean_grouped)
# Out:
#                 tax_collected  consumption  tax_per_person
# region
# California           728045.0    1835981.0        0.018479
# Texas               1228641.0    1164466.0        0.043380
# New York            1265699.0     976857.0        0.064607
# Florida              323393.0     947906.0        0.015417
# Pennsylvania         930210.0     577036.0        0.072727
# Illinois             388038.5     559565.0        0.030348
# Ohio                 134505.0     466160.0        0.011532
# New Jersey           565736.0     446078.0        0.063648
# Michigan             198226.5     411916.0        0.019869
# Georgia              193438.0     408753.0        0.018576
# North Carolina       103206.5     405953.0        0.010049
# Virginia             223721.0     367303.0        0.026428
# Massachusetts        330251.0     364730.0        0.048119
# Washington           393934.0     354219.0        0.053052
# Arizona               74126.0     287090.0        0.010516
# Maryland             227940.0     273980.0        0.037833
# Colorado              65122.0     270883.0        0.011596
# Tennessee            236169.0     258252.0        0.035203
# Indiana              193613.0     257343.0        0.029071
# Minnesota            129657.0     255154.0        0.023285
# Missouri              75900.0     246053.0        0.012425
# Wisconsin             83830.0     238923.0        0.014473
# South Carolina       117141.0     195959.0        0.023329
# Connecticut          218789.0     181568.0        0.061219
# Oregon                55759.0     178375.0        0.013447
# Alabama              100665.0     176480.0        0.020649
# Louisiana            143548.0     173521.0        0.030733
# Kentucky             135558.0     163750.0        0.030436
# Oklahoma              42267.0     137469.0        0.010748
# Nevada               227798.5     123054.0        0.076638
# Utah                  55350.0     119970.0        0.017837
# Iowa                  62575.0     119390.0        0.019905
# Kansas                52731.0     113185.0        0.018116
# Arkansas              58105.5     104430.0        0.019349
# Mississippi           78606.0      95998.0        0.026293
# Nebraska              25797.0      79714.0        0.013453
# New Mexico            61437.5      74540.0        0.029348
# New Hampshire         77932.5      70719.0        0.057738
# West Virginia         73338.5      66584.0        0.040361
# Hawaii               104021.0      64439.0        0.073038
# Idaho                 46884.5      63986.0        0.027276
# Maine                 43906.0      61124.0        0.032887
# Rhode Island          64367.0      45923.0        0.060926
# Montana               59093.5      45545.0        0.056114
# Delaware              55890.0      44834.0        0.058396
# South Dakota          23649.0      37338.0        0.027080
# Alaska                39498.5      36645.0        0.053392
# North Dakota          46595.0      34104.0        0.061701
# Vermont               38857.0      30020.0        0.062218
# Wyoming               29652.5      24467.0        0.051219

# %%
data_clean_grouped.plot.bar(subplots=True, figsize=(28, 38));

# %% [markdown]
# ### Conclusion:
# -  the highest tax per person is 0.38 mln $ in **North Dakota**.

# %% [markdown]
# ### 3.2 Determine state with the third largest amount of collected taxes.

# %%
data_clean.dtypes
# Out:
# region             object
# state_code        float64
# tax_name           object
# tax_code           object
# tax_collected       int64
# year              float64
# consumption         int64
# include?           object
# population          int64
# tax_per_person    float64
# dtype: object

# %%
tax_collected = data_clean.groupby('region')['tax_collected'].agg(['mean']).sort_values(by='mean', ascending=False).head(10)
tax_collected.reset_index(inplace=True) # resetting indexed from 0 again
tax_collected
# Out:
#          region          mean
# 0    California  5.716945e+06
# 1         Texas  5.282273e+06
# 2       Florida  3.456232e+06
# 3      New York  3.184523e+06
# 4  Pennsylvania  2.397347e+06
# 5      Illinois  2.098533e+06
# 6    Washington  2.013389e+06
# 7          Ohio  1.993273e+06
# 8    New Jersey  1.669232e+06
# 9      Michigan  1.505789e+06

# %% [markdown]
# ### Conclusion
# -  the state with 3rd largest amount of taxes is **Florida**.

# %% [markdown]
# ### 3.3 Name region with the smallest value of sum of "Individual Income Taxes" and "Income Taxes"

# %%
data_clean.columns
# Out:
# Index(['region', 'state_code', 'tax_name', 'tax_code', 'tax_collected', 'year',
#        'consumption', 'include?', 'population', 'tax_per_person'],
#       dtype='object')

# %% [markdown]
# - **Individual Income Taxes**

# %% [markdown]
# Filter the dataset only for **Individual Income Taxes**.

# %%
ind_income_tax = data_clean[data_clean['tax_name'] == 'Individual Income Taxes']
ind_income_tax
# Out:
# Empty DataFrame
# Columns: [region, state_code, tax_name, tax_code, tax_collected, year, consumption, include?, population, tax_per_person]
# Index: []

# %%
ind_income_tax_grouped = ind_income_tax.groupby('region')['tax_collected'].agg(['sum']).sort_values(by='sum', ascending=False).tail(10)
ind_income_tax_grouped.reset_index(inplace=True) # resetting indexed from 0 again
ind_income_tax_grouped
# Out:
# Empty DataFrame
# Columns: [region, sum]
# Index: []

# %% [markdown]
# ### Conclusion
# -  there are no individual income taxes sliced as 'included?' - 'no'.
#
# _To be noticed: in the given task it is required to use only 'included?' = 'no' slice of data through all tasks._

# %% [markdown]
# - **Income Taxes**

# %% [markdown]
# Filter the dataset only for **Income Taxes**.

# %%
income_tax = data_clean[data_clean['tax_name'] == 'Income Taxes']
income_tax
# Out:
# Empty DataFrame
# Columns: [region, state_code, tax_name, tax_code, tax_collected, year, consumption, include?, population, tax_per_person]
# Index: []

# %%
income_tax_grouped = income_tax.groupby('region')['tax_collected'].agg(['sum']).sort_values(by='sum', ascending=False).tail(10)
income_tax_grouped.reset_index(inplace=True) # resetting indexed from 0 again
income_tax_grouped
# Out:
# Empty DataFrame
# Columns: [region, sum]
# Index: []

# %% [markdown]
# ### Conclusion
# -  there are no income taxes sliced as 'included?' - 'no'.
#
# _To be noticed: in the given task it is required to use only 'included?' = 'no' slice of data through all tasks._

# %% [markdown]
# ### 3.4 Calculate percent changes of personal consumption expenditures between 2018 and 2020 for each state and determine state and year with highest change (example: Florida 2018/2019)

# %%
data_clean['cons_per_person'] = data_clean['consumption'] / data_clean['population']
data_clean
# Out:
#       region  state_code                                tax_name tax_code  \
# 0      Maine        20.0          Sales and Gross Receipts Taxes      TA1
# 1      Maine        20.0          Sales and Gross Receipts Taxes      TA1
# 2      Maine        20.0          Sales and Gross Receipts Taxes      TA1
# 3      Maine        20.0  General Sales and Gross Receipts Taxes      T09
# 4      Maine        20.0  General Sales and Gross Receipts Taxes      T09
# ...      ...         ...                                     ...      ...
# 3415  Hawaii        12.0   Documentarty and Stock Transfer Taxes      T51
# 3416  Hawaii        12.0   Documentarty and Stock Transfer Taxes      T51
# 3417  Hawaii        12.0                               Taxes NEC      T99
# 3418  Hawaii        12.0                               Taxes NEC      T99
# 3419  Hawaii        12.0                               Taxes NEC      T99
#
#       tax_collected    year  consumption include?  population  tax_per_person  \
# 0           2165142  2018.0        60086       no     1335063        1.621753
# 1           2165142  2019.0        62130       no     1335063        1.621753
# 2           2165142  2020.0        61124       no     1335063        1.621753
# 3           1441867  2018.0        60086       no     1335063        1.079999
# 4           1441867  2019.0        62130       no     1335063        1.079999
# ...             ...     ...          ...      ...         ...             ...
# 3415          94537  2019.0        66977       no     1424203        0.066379
# 3416          94537  2020.0        63427       no     1424203        0.066379
# 3417              0  2018.0        64439       no     1424203        0.000000
# 3418              0  2019.0        66977       no     1424203        0.000000
# 3419              0  2020.0        63427       no     1424203        0.000000
#
#       cons_per_person
# 0            0.045006
# 1            0.046537
# 2            0.045784
# 3            0.045006
# 4            0.046537
# ...               ...
# 3415         0.047028
# 3416         0.044535
# 3417         0.045246
# 3418         0.047028
# 3419         0.044535
#
# [3420 rows x 11 columns]

# %% [markdown]
# Group data per two columns _'region', 'year'_.

# %%
cons_per_person_grouped = data_clean.groupby(['region', 'year'], as_index = False)['cons_per_person'].agg(['mean']).sort_values(by='mean', ascending=False)
cons_per_person_grouped
# Out:
#                           mean
# region        year
# Massachusetts 2019.0  0.055015
# New Hampshire 2019.0  0.053365
# Massachusetts 2018.0  0.053142
# New Hampshire 2020.0  0.052393
# Massachusetts 2020.0  0.052231
# ...                        ...
# Oklahoma      2018.0  0.034578
# Arkansas      2018.0  0.033875
# Mississippi   2019.0  0.032289
#               2020.0  0.032110
#               2018.0  0.031703
#
# [150 rows x 1 columns]

# %% [markdown]
# Calculate the consumption percentage change between years.

# %%
cons_change = cons_per_person_grouped.pct_change().sort_values('mean')
cons_change
# Out:
#                               mean
# region        year
# Mississippi   2019.0 -4.681604e-02
# New Hampshire 2019.0 -3.000255e-02
# Arkansas      2018.0 -2.032751e-02
# New Hampshire 2020.0 -1.409429e-02
# Mississippi   2018.0 -1.266693e-02
# ...                            ...
# Ohio          2019.0 -1.332836e-04
# Missouri      2019.0 -9.337199e-05
# North Dakota  2020.0 -2.457400e-05
# Minnesota     2020.0 -5.135175e-07
# Massachusetts 2019.0           NaN
#
# [150 rows x 1 columns]

# %% [markdown]
# Indexes were destroyed after manupulation.

# %%
cons_change.index
# Out:
# MultiIndex([(  'Mississippi', 2019.0),
#             ('New Hampshire', 2019.0),
#             (     'Arkansas', 2018.0),
#             ('New Hampshire', 2020.0),
#             (  'Mississippi', 2018.0),
#             (  'Connecticut', 2020.0),
#             (        'Idaho', 2018.0),
#             (     'Illinois', 2018.0),
#             (     'Colorado', 2020.0),
#             (     'Kentucky', 2020.0),
#             ...
#             (   'New Jersey', 2020.0),
#             (    'Tennessee', 2019.0),
#             (         'Utah', 2018.0),
#             (   'California', 2018.0),
#             (         'Iowa', 2020.0),
#             (         'Ohio', 2019.0),
#             (     'Missouri', 2019.0),
#             ( 'North Dakota', 2020.0),
#             (    'Minnesota', 2020.0),
#             ('Massachusetts', 2019.0)],
#            names=['region', 'year'], length=150)

# %% [markdown]
# Reset indexes in the grouped data.

# %%
cons_change.reset_index(inplace=True)

# %%
cons_change.columns # check indexes now
# Out:
# Index(['region', 'year', 'mean'], dtype='object')

# %% [markdown]
# Create a new variable for maximun mean value in each year (2018, 2019, 2020).

# %%
change2018 = cons_change[cons_change['year'] == 2018]['mean'].max()

# %%
change2019 = cons_change[cons_change['year'] == 2019]['mean'].max()

# %%
change2020 = cons_change[cons_change['year'] == 2020]['mean'].max()

# %% [markdown]
# Get a result of the changes in each year.

# %%
result_change = cons_change[cons_change['mean'].isin([change2018, change2019, change2020])]
result_change
# Out:
#          region    year          mean
# 143  California  2018.0 -1.884551e-04
# 146    Missouri  2019.0 -9.337199e-05
# 148   Minnesota  2020.0 -5.135175e-07

# %% [markdown]
# ### Conclusion:
# - In 2018 the highest change in consumption was in **California**.
# - In 2019 the hughest change in consumption was in **Missouri**.
# - In 2020 the highest change in consumption was in **Minnesota**.
#
# All the changes a negative, meaning people consume less each year.

# %% [markdown]
# ### 3.5 Determine Region with the highest average Personal Consumption Expenditures per person in 2020

# %%
data_clean['cons_per_person'] = data_clean['consumption'] / data_clean['population']
data_clean['cons_per_person']
# Out:
# 0       0.045006
# 1       0.046537
# 2       0.045784
# 3       0.045006
# 4       0.046537
#           ...
# 3415    0.047028
# 3416    0.044535
# 3417    0.045246
# 3418    0.047028
# 3419    0.044535
# Name: cons_per_person, Length: 3420, dtype: float64

# %%
consumption2020 = data_clean[data_clean['year'] == 2020]
consumption2020
# Out:
#       region  state_code                                  tax_name tax_code  \
# 2      Maine        20.0            Sales and Gross Receipts Taxes      TA1
# 5      Maine        20.0    General Sales and Gross Receipts Taxes      T09
# 8      Maine        20.0  Selective Sales and Gross Receipts Taxes      TA2
# 11     Maine        20.0             Alcoholic Beverages Sales Tax      T10
# 14     Maine        20.0                      Amusements Sales Tax      T11
# ...      ...         ...                                       ...      ...
# 3407  Hawaii        12.0                       Other License Taxes      T29
# 3410  Hawaii        12.0                               Other Taxes      TA5
# 3413  Hawaii        12.0                      Death and Gift Taxes      T50
# 3416  Hawaii        12.0     Documentarty and Stock Transfer Taxes      T51
# 3419  Hawaii        12.0                                 Taxes NEC      T99
#
#       tax_collected    year  consumption include?  population  tax_per_person  \
# 2           2165142  2020.0        61124       no     1335063        1.621753
# 5           1441867  2020.0        61124       no     1335063        1.079999
# 8            723275  2020.0        61124       no     1335063        0.541753
# 11            19266  2020.0        61124       no     1335063        0.014431
# 14            54400  2020.0        61124       no     1335063        0.040747
# ...             ...     ...          ...      ...         ...             ...
# 3407          12647  2020.0        63427       no     1424203        0.008880
# 3410         113505  2020.0        63427       no     1424203        0.079697
# 3413          18968  2020.0        63427       no     1424203        0.013318
# 3416          94537  2020.0        63427       no     1424203        0.066379
# 3419              0  2020.0        63427       no     1424203        0.000000
#
#       cons_per_person
# 2            0.045784
# 5            0.045784
# 8            0.045784
# 11           0.045784
# 14           0.045784
# ...               ...
# 3407         0.044535
# 3410         0.044535
# 3413         0.044535
# 3416         0.044535
# 3419         0.044535
#
# [1140 rows x 11 columns]

# %%
consumption = consumption2020.groupby('region')['consumption'].agg(['mean']).sort_values(by='mean', ascending=False).head(10)
consumption.reset_index(inplace=True) # resetting indexed from 0 again

consumption
# Out:
#          region       mean
# 0    California  1835981.0
# 1         Texas  1164466.0
# 2      New York   961707.0
# 3       Florida   947906.0
# 4  Pennsylvania   570772.0
# 5      Illinois   553612.0
# 6          Ohio   466160.0
# 7    New Jersey   446078.0
# 8      Michigan   411364.0
# 9       Georgia   408753.0

# %% [markdown]
# ### Conclusion
# -  **California** is the highest average Personal Consumption Expenditures per person in 2020 (1835981$).

# %% [markdown]
# ## 4. Data Visualization _(Tableau dashboarding)_

# %%
# writing to xlsx dataset for visualization
tax_data = data_clean.to_excel('/Users/yuliabezginova/PycharmProjects/income_tax/tax_data.xlsx')

# %% [markdown]
# Tableau workbook: https://dub01.online.tableau.com/#/site/yuliabezginova/workbooks/948545?:origin=card_share_link

# %% [markdown]
# ### 4.1 Amount of taxes collected per person in each state

# %% [markdown]
# ![1_Tax%20per%20person%20in%20each%20state.jpg](attachment:1_Tax%20per%20person%20in%20each%20state.jpg)

# %% [markdown]
# ### 4.2 Amount of taxes collected in each state

# %% [markdown]
# ![2_Tax%20collected%20in%20each%20state.jpg](attachment:2_Tax%20collected%20in%20each%20state.jpg)

# %% [markdown]
# ### 4.3 Breakdown of collected taxes (tax types)

# %% [markdown]
# ![3_Breakdown%20of%20collected%20taxes%20%28tax%20types%29.jpg](attachment:3_Breakdown%20of%20collected%20taxes%20%28tax%20types%29.jpg)

# %% [markdown]
# ### 4.4 How value of personal consumption expenditures has changed in time.

# %% [markdown]
# ![4_How%20value%20of%20personal%20consumption%20expenditures%20has%20changed%20.jpg](attachment:4_How%20value%20of%20personal%20consumption%20expenditures%20has%20changed%20.jpg)

# %% [markdown]
# ### 4.5 Ranking of regions based on average value of personal consumption expenditures per person.

# %% [markdown]
# ![5_Ranking%20of%20regions%20based%20on%20average%20value%20of%20personal%20consumption%20expenditures%20per%20person.jpg](attachment:5_Ranking%20of%20regions%20based%20on%20average%20value%20of%20personal%20consumption%20expenditures%20per%20person.jpg)

# %% [markdown]
# ### Tools used for this project:
# - Python (Jupyter, pandas, matpplotlib)
# - Tableau dashboards

# %% [markdown]
# _Thank you for going through this project. Your feedback and comments are very welcome to_ **_ybezginova2021@gmail.com_**
#
# _Thank you!_
#
# _Best wishes,_
#
# _Yulia_
